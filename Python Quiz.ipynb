# %% [markdown]
# # Live Python Quiz

# %% [markdown]
# #### Problem Statement
# - input - Answers
# - output - score
# - default - que with 4 options

# %%
### print("****** Python Quiz ******")
print("All The Best!")
score = 0

# Q1
print("\nQ.1. What is Python?")
print("A. Programming Language")
print("B. Operating System")
print("C. Compiler")
print("D. Website")
a1 = input("Enter your Answer: ")
if a1.upper() == "A":
    score += 1
print(f"Your Current Score: {score}")

# Q2
print("\nQ.2. How many pillars does OOPs have?")
print("A. 5")
print("B. 4")
print("C. 3")
print("D. 0")
a2 = input("Enter your Answer: ")
if a2.upper() == "B":
    score += 1
print(f"Your Current Score: {score}")

# Q3
print("\nQ.3. Which keyword is used to define a function in Python?")
print("A. function")
print("B. define")
print("C. def")
print("D. fun")
a3 = input("Enter your Answer: ")
if a3.upper() == "C":
    score += 1
print(f"Your Current Score: {score}")

# Q4
print("\nQ.4. Which of the following is a mutable data type?")
print("A. Tuple")
print("B. List")
print("C. String")
print("D. Integer")
a4 = input("Enter your Answer: ")
if a4.upper() == "B":
    score += 1
print(f"Your Current Score: {score}")

# Q5
print("\nQ.5. Which symbol is used for comments in Python?")
print("A. //")
print("B. /* */")
print("C. #")
print("D. <!-- -->")
a5 = input("Enter your Answer: ")
if a5.upper() == "C":
    score += 1
print(f"Your Current Score: {score}")

# Q6
print("\nQ.6. What does 'len()' function do?")
print("A. Adds numbers")
print("B. Finds length")
print("C. Converts to string")
print("D. Prints output")
a6 = input("Enter your Answer: ")
if a6.upper() == "B":
    score += 1
print(f"Your Current Score: {score}")

# Q7
print("\nQ.7. What is the correct file extension for Python files?")
print("A. .pt")
print("B. .pyt")
print("C. .py")
print("D. .pyth")
a7 = input("Enter your Answer: ")
if a7.upper() == "C":
    score += 1
print(f"Your Current Score: {score}")

# Q8
print("\nQ.8. Which function is used to display output in Python?")
print("A. display()")
print("B. echo()")
print("C. show()")
print("D. print()")
a8 = input("Enter your Answer: ")
if a8.upper() == "D":
    score += 1
print(f"\nYour Final Score is {score}/8 🎯")
# Out:
# All The Best!
#
# Q.1. What is Python?
# A. Programming Language
# B. Operating System
# C. Compiler
# D. Website
# Enter your Answer:  A
# Your Current Score: 1
#
# Q.2. How many pillars does OOPs have?
# A. 5
# B. 4
# C. 3
# D. 0
# Enter your Answer:  B
# Your Current Score: 2
#
# Q.3. Which keyword is used to define a function in Python?
# A. function
# B. define
# C. def
# D. fun
# Enter your Answer:  C
# Your Current Score: 3
#
# Q.4. Which of the following is a mutable data type?
# A. Tuple
# B. List
# C. String
# D. Integer
# Enter your Answer:  B
# Your Current Score: 4
#
# Q.5. Which symbol is used for comments in Python?
# A. //
# B. /* */
# C. #
# D. <!-- -->
# Enter your Answer:  C
# Your Current Score: 5
#
# Q.6. What does 'len()' function do?
# A. Adds numbers
# B. Finds length
# C. Converts to string
# D. Prints output
# Enter your Answer:  B
# Your Current Score: 6
#
# Q.7. What is the correct file extension for Python files?
# A. .pt
# B. .pyt
# C. .py
# D. .pyth
# ...
